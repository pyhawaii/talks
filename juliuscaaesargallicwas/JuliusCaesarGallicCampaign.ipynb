# %% [markdown]
# # Fetching

# %% [markdown]
# In order to process text that is available online, we'll need to fetch the text with Python's urllib. We call on the request module to fetch content from classics.mit.edu.
#
# What we get in the output is an indication that the raw text is a string. (Official documentation https://docs.python.org/3.5/library/string.html)
#
# NBViewer: http://nbviewer.jupyter.org/github/crimsonpresident/JuliusCaesarGallicWars/blob/master/JuliusCaesarGallicCampaign.ipynb

# %%
import nltk
from urllib import request
url = "http://classics.mit.edu/Caesar/gallic.mb.txt"
response = request.urlopen(url)
raw = response.read().decode('utf8')
type(raw)
# Out:
# str

# %% [markdown]
# At this point, I will tokenize the raw file and create a list, which reveals there are 99,328 tokens.

# %%
tokens = nltk.word_tokenize(raw)
type(tokens)
# Out:
# list

# %%
len(tokens)
# Out:
# 99328

# %% [markdown]
# # Need to Normalize

# %% [markdown]
# Based on the text and the NLTK library, we can identify the first several tokens. In this case, the first eight are: Provided, by, The, Internet, Classics, Archive, . , and See. One of the first things you notice is the non-uniformity of cases. Also, the full stop glyph or period has been tokenized and was included in the aforementioned 99,328 universe.

# %%
tokens[:8]
# Out:
# ['Provided', 'by', 'The', 'Internet', 'Classics', 'Archive', '.', 'See']

# %% [markdown]
# Normalizing by de-uppercasifying and removing punctuation can be achieved by: [w.lower() for w in tokens if w.islpha()] as seen below. The output will showcase all normalized tokens and the removal of the full stop glyph or period that was seen above.
#
# The normalized tokens are: provided, by, the, internet, classics, archive, see, and bottom. After the removal of punctuations, there are 85,930 tokens. However, our cleaning is not yet done.

# %%
tokens = nltk.word_tokenize(raw)
tokens = [w.lower() for w in  tokens if w.isalpha()]
tokens[:8]
# Out:
# ['provided', 'by', 'the', 'internet', 'classics', 'archive', 'see', 'bottom']

# %%
len(tokens)
# Out:
# 85930

# %% [markdown]
# # Frequency and Visualization

# %% [markdown]
# In these next steps, we will attempt to figure out the frequency of each word and then visualize the most and least common tokens. When utilizing the FreqDist module, I noticed that the most common words were stopwords (...the, of, and, to, that, etc.).

# %%
fdist1 = nltk.FreqDist(tokens)
print(fdist1)
# Out:
# <FreqDist with 5584 samples and 85930 outcomes>

# %%
fdist1.N()
# Out:
# 85930

# %%
fdist1.hapaxes()
# Out:
# ['sue',
#  'raises',
#  'segontiaci',
#  'forasmuch',
#  'commends',
#  'barely',
#  'die',
#  'neighbouring',
#  'east',
#  'encamp',
#  'resulted',
#  'solicited',
#  'drag',
#  'artifice',
#  'protecting',
#  'subjected',
#  'muster',
#  'straggling',
#  'emigrate',
#  'repelling',
#  'reparation',
#  'costly',
#  'indignity',
#  'curisolites',
#  'contents',
#  'bends',
#  'huge',
#  'concentrated',
#  'woman',
#  'unequal',
#  'resigned',
#  'delivers',
#  'causes',
#  'active',
#  'conduce',
#  'usage',
#  'agger',
#  'meritorious',
#  'invincible',
#  'verses',
#  'dearer',
#  'conjectured',
#  'doom',
#  'beforehand',
#  'strengthen',
#  'relates',
#  'facility',
#  'forfeit',
#  'reserves',
#  'courteous',
#  'domains',
#  'doctrines',
#  'connects',
#  'verbigene',
#  'dressed',
#  'telling',
#  'blot',
#  'intend',
#  'triviri',
#  'terminated',
#  'apathy',
#  'marcomanni',
#  'tendency',
#  'prison',
#  'congratulate',
#  'fenny',
#  'rashly',
#  'bull',
#  'accomplishments',
#  'caltes',
#  'sinews',
#  'intimated',
#  'announcements',
#  'disband',
#  'wrecked',
#  'tampers',
#  'mismanagement',
#  'reign',
#  'sincere',
#  'severest',
#  'swerve',
#  'nasuas',
#  'wherever',
#  'overrun',
#  'cretan',
#  'bibroci',
#  'bewailed',
#  'impressed',
#  'adopts',
#  'foe',
#  'prolonged',
#  'variety',
#  'gabinius',
#  'swells',
#  'ordains',
#  'excellence',
#  'changes',
#  'ends',
#  'reproduction',
#  'diligent',
#  'extinguishing',
#  'straighter',
#  'grievously',
#  'testing',
#  'approving',
#  'desolate',
#  'breach',
#  'invade',
#  'dams',
#  'munatius',
#  'wheel',
#  'caletes',
#  'intent',
#  'spends',
#  'slipping',
#  'worsted',
#  'espies',
#  'imprecation',
#  'trains',
#  'cabillo',
#  'informers',
#  'licentiousness',
#  'invitation',
#  'tarbelli',
#  'squadron',
#  'midland',
#  'torches',
#  'excel',
#  'roes',
#  'approximity',
#  'interpret',
#  'reminds',
#  'eratosthenes',
#  'droughts',
#  'ram',
#  'ambiliati',
#  'inches',
#  'buckler',
#  'ranges',
#  'detains',
#  'upbraided',
#  'deserting',
#  'detriment',
#  'excitement',
#  'propitious',
#  'growth',
#  'equally',
#  'wealth',
#  'misgivings',
#  'watchword',
#  'guests',
#  'census',
#  'defensible',
#  'wrongfully',
#  'winters',
#  'guise',
#  'reckon',
#  'alienate',
#  'rammers',
#  'influential',
#  'requires',
#  'machines',
#  'seas',
#  'enlisted',
#  'memoirs',
#  'outstripped',
#  'pull',
#  'drought',
#  'convicts',
#  'mixed',
#  'exercises',
#  'lament',
#  'consoles',
#  'arbitrators',
#  'octodurus',
#  'hindmost',
#  'tolerance',
#  'acquisition',
#  'expired',
#  'diets',
#  'translated',
#  'valetiacus',
#  'intermediate',
#  'sow',
#  'adjoining',
#  'onslaught',
#  'vacant',
#  'society',
#  'shelves',
#  'vergobretus',
#  'scouring',
#  'heavenly',
#  'relative',
#  'abstained',
#  'struggled',
#  'numeius',
#  'sires',
#  'shoals',
#  'imparts',
#  'urge',
#  'fostered',
#  'patrons',
#  'doubts',
#  'organize',
#  'concedes',
#  'endeavoured',
#  'poorer',
#  'pleads',
#  'bratuspantium',
#  'whithersoever',
#  'interview',
#  'ubian',
#  'increase',
#  'god',
#  'content',
#  'censures',
#  'solemn',
#  'atone',
#  'sounded',
#  'muleteers',
#  'manilius',
#  'antagonists',
#  'sixteen',
#  'sanction',
#  'prohibition',
#  'promote',
#  'forms',
#  'slow',
#  'crates',
#  'elsewhere',
#  'invites',
#  'reconciled',
#  'discuss',
#  'childhood',
#  'perpendicularly',
#  'elicit',
#  'hire',
#  'yields',
#  'flattered',
#  'mortal',
#  'quick',
#  'brushwood',
#  'directing',
#  'wandered',
#  'dowry',
#  'breed',
#  'exhibited',
#  'tools',
#  'disquieted',
#  'sell',
#  'defenses',
#  'closer',
#  'forcibly',
#  'exhort',
#  'relate',
#  'masts',
#  'reckoning',
#  'hung',
#  'contrivance',
#  'beseiged',
#  'knows',
#  'altrebatian',
#  'extolled',
#  'laden',
#  'decidedly',
#  'quietly',
#  'plainly',
#  'stems',
#  'filling',
#  'irregular',
#  'galling',
#  'principle',
#  'backward',
#  'thatched',
#  'addicted',
#  'distinguish',
#  'consequences',
#  'braces',
#  'corps',
#  'surrendering',
#  'flock',
#  'pair',
#  'stag',
#  'history',
#  'pleaded',
#  'nearness',
#  'waal',
#  'wings',
#  'launched',
#  'keenly',
#  'confiscates',
#  'uttered',
#  'inflated',
#  'strict',
#  'huntsmen',
#  'weakened',
#  'poles',
#  'urges',
#  'published',
#  'reverse',
#  'additions',
#  'confide',
#  'wrested',
#  'refreshed',
#  'shunned',
#  'utterly',
#  'compasses',
#  'forsaken',
#  'prize',
#  'belly',
#  'contact',
#  'traced',
#  'choicest',
#  'fish',
#  'sesuvii',
#  'tributary',
#  'reaped',
#  'overtaking',
#  'accuse',
#  'entertains',
#  'beginnings',
#  'priesthood',
#  'venetic',
#  'fix',
#  'rigor',
#  'speaking',
#  'appreciate',
#  'tips',
#  'cried',
#  'tarrying',
#  'reap',
#  'invent',
#  'title',
#  'crowding',
#  'grows',
#  'catastrophe',
#  'measuring',
#  'sank',
#  'punctually',
#  'dust',
#  'arts',
#  'lemovici',
#  'timid',
#  'http',
#  'pikes',
#  'erect',
#  'versed',
#  'conferences',
#  'severer',
#  'disregard',
#  'total',
#  'clansmen',
#  'prince',
#  'preference',
#  'alacrity',
#  'intolerable',
#  'royalty',
#  'rowers',
#  'counsels',
#  'racked',
#  'burst',
#  'veterans',
#  'unskilfulness',
#  'crafty',
#  'naught',
#  'boduognatus',
#  'injunctions',
#  'assaulting',
#  'grants',
#  'ourselves',
#  'behaved',
#  'belgians',
#  'selecting',
#  'internal',
#  'assent',
#  'consisted',
#  'acknowledge',
#  'questors',
#  'thraldom',
#  'daughters',
#  'descents',
#  'composition',
#  'troop',
#  'correctness',
#  'opponents',
#  'dispirited',
#  'vangiones',
#  'provocation',
#  'uncle',
#  'accounted',
#  'tin',
#  'unfit',
#  'showers',
#  'resolute',
#  'burial',
#  'weakens',
#  'staying',
#  'obliquely',
#  'infatuation',
#  'obscure',
#  'dispensing',
#  'taunted',
#  'persevere',
#  'pitches',
#  'managing',
#  'burn',
#  'slackening',
#  'create',
#  'assiduity',
#  'munificence',
#  'deer',
#  'weakest',
#  'base',
#  'affixing',
#  'humor',
#  'subsist',
#  'outer',
#  'eburovices',
#  'curio',
#  'insnared',
#  'aspect',
#  'colors',
#  'cultivating',
#  'dike',
#  'crush',
#  'expeditiously',
#  'wonted',
#  'warily',
#  'intimidating',
#  'drying',
#  'vienna',
#  'frightened',
#  'clapping',
#  'ward',
#  'coldness',
#  'diablintes',
#  'killing',
#  'suggest',
#  'admiration',
#  'forget',
#  'equitable',
#  'safer',
#  'workmen',
#  'lances',
#  'difference',
#  'whilst',
#  'unsupported',
#  'esubii',
#  'estuaries',
#  'catamantaledes',
#  'leaned',
#  'special',
#  'tired',
#  'disciplined',
#  'servants',
#  'mildness',
#  'stars',
#  'amazed',
#  'prepares',
#  'antebrogius',
#  'prescribe',
#  'legs',
#  'inferred',
#  'conveys',
#  'joins',
#  'gallus',
#  'remains',
#  'celtillus',
#  'breaks',
#  'praeconinus',
#  'redoubt',
#  'prescribes',
#  'blocking',
#  'repulsing',
#  'consigned',
#  'vocion',
#  'excursion',
#  'deed',
#  'confining',
#  'stretching',
#  'promotion',
#  'animosities',
#  'contributes',
#  'ladders',
#  'story',
#  'lily',
#  'cool',
#  'undetermined',
#  'tone',
#  'boasting',
#  'tore',
#  'virgin',
#  'watches',
#  'infirmity',
#  'conspired',
#  'inquiry',
#  'pleased',
#  'ascribed',
#  'travel',
#  'ireland',
#  'wreak',
#  'shower',
#  'calmly',
#  'detachments',
#  'petreius',
#  'justifies',
#  'rout',
#  'won',
#  'provincial',
#  'touches',
#  'existed',
#  'instigator',
#  'marshy',
#  'deceive',
#  'puffed',
#  'ashamed',
#  'introduction',
#  'remedied',
#  'quickened',
#  'petrocorii',
#  'devices',
#  'stake',
#  'steady',
#  'levaci',
#  'cocosates',
#  'concourse',
#  'selection',
#  'spontaneous',
#  'funerals',
#  'english',
#  'sure',
#  'compute',
#  'undertaking',
#  'rumored',
#  'imprudence',
#  'consulting',
#  'vosge',
#  'enters',
#  'eat',
#  'atius',
#  'mistaken',
#  'trustworthy',
#  'cadurcian',
#  'benefits',
#  'pronounce',
#  'pit',
#  'concerned',
#  'tenets',
#  'judges',
#  'respectively',
#  'bsg',
#  'exchange',
#  'broader',
#  'aemilius',
#  'bigerriones',
#  'bohn',
#  'indecorous',
#  'glorious',
#  'amongst',
#  'benefit',
#  'dis',
#  'appius',
#  'reference',
#  'disturbed',
#  'methods',
#  'ambivariti',
#  'tear',
#  'paulus',
#  'obedience',
#  'robbery',
#  'pardons',
#  'passionate',
#  'released',
#  'reinforcements',
#  'settlement',
#  'converted',
#  'declines',
#  'showing',
#  'orb',
#  'abide',
#  'especial',
#  'timidly',
#  'surus',
#  'fierceness',
#  'avow',
#  'dense',
#  'punishing',
#  'victims',
#  'criminal',
#  'indigence',
#  'started',
#  'renowned',
#  'abode',
#  'meditated',
#  'investigated',
#  'insist',
#  'confirms',
#  'impending',
#  'instigation',
#  'pristine',
#  'wherein',
#  'thin',
#  'mouth',
#  'saving',
#  'innermost',
#  'earnestness',
#  'paused',
#  'entrap',
#  'offering',
#  'myself',
#  'bullets',
#  'intending',
#  'achieve',
#  'items',
#  'arveni',
#  'maintaining',
#  'firstly',
#  'forum',
#  'ambibari',
#  'falling',
#  'garites',
#  'falls',
#  'foresight',
#  'innate',
#  'compiled',
#  'vertiscus',
#  'contributing',
#  'fir',
#  'pierces',
#  'gale',
#  'establish',
#  'privations',
#  'confounded',
#  'infamous',
#  'reconnoitering',
#  'fraternal',
#  'sulla',
#  'hardihood',
#  'bay',
#  'prodigious',
#  'dominions',
#  'timbers',
#  'fatigued',
#  'wrote',
#  'donotaurus',
#  'giddy',
#  'false',
#  'outlaws',
#  'answered',
#  'earned',
#  'pushed',
#  'refusals',
#  'imposts',
#  'examines',
#  'disciplining',
#  'goose',
#  'wealthy',
#  'propelled',
#  'soil',
#  'enlarging',
#  'economy',
#  'wholly',
#  'insufficient',
#  'aught',
#  'britains',
#  'ascended',
#  'sedusii',
#  'viewing',
#  'blows',
#  'yells',
#  'soldurii',
#  'determinately',
#  'mustering',
#  'disengaged',
#  'apportion',
#  'imitating',
#  'congratulations',
#  'injurious',
#  'concurring',
#  'depraved',
#  'dictated',
#  'benches',
#  'real',
#  'elurates',
#  'perseveres',
#  'molested',
#  'requests',
#  'lord',
#  'profession',
#  'conferring',
#  'sestertii',
#  'camalugenus',
#  'sum',
#  'awed',
#  'adjacent',
#  'mud',
#  'random',
#  'ranged',
#  'framed',
#  'deliberations',
#  'divination',
#  'funeral',
#  'marshal',
#  'insolently',
#  'adhere',
#  'seat',
#  'cotuatus',
#  'theft',
#  'fierce',
#  'rose',
#  'disclosure',
#  'irons',
#  'insured',
#  'taunt',
#  'stopping',
#  'reads',
#  'proximity',
#  'clodius',
#  'enamored',
#  'reasonable',
#  'canvas',
#  'assail',
#  'facing',
#  'incur',
#  'traders',
#  'cippi',
#  'demurs',
#  'respite',
#  'injuring',
#  'forbids',
#  'decides',
#  'terrible',
#  'supplication',
#  'speediness',
#  'reflecting',
#  'ensnared',
#  'opportunities',
#  'courteously',
#  'unprovided',
#  'nineteen',
#  'opportune',
#  'prows',
#  'institution',
#  'locked',
#  'viewed',
#  'oblique',
#  'circuitous',
#  'characteristic',
#  'horn',
#  'doubted',
#  'deciding',
#  'unhappy',
#  'creating',
#  'survey',
#  'temperate',
#  'treats',
#  'exiles',
#  'dissatisfied',
#  'kings',
#  'perfect',
#  'tribuci',
#  'discloses',
#  'banished',
#  'noreia',
#  'deceiving',
#  'crushed',
#  'emissaries',
#  'strenuously',
#  'january',
#  'rouses',
#  'scabbard',
#  'quantities',
#  'perpetrators',
#  'refresh',
#  'abhorrence',
#  'demanding',
#  'clandestine',
#  'performers',
#  'heated',
#  'concentrate',
#  'treasurer',
#  'fomented',
#  'impale',
#  'cenomani',
#  'barricaded',
#  'propriety',
#  'organized',
#  'propensity',
#  'deprecate',
#  'captivity',
#  'tamed',
#  'abated',
#  'mostly',
#  'eras',
#  'contingency',
#  'gushed',
#  'stowed',
#  'annexed',
#  'intercourse',
#  'combination',
#  'gestures',
#  'machine',
#  'studying',
#  'propose',
#  'interdict',
#  'occupying',
#  'blew',
#  'battering',
#  'commonality',
#  'permits',
#  'purposed',
#  'richer',
#  'virtues',
#  'forgives',
#  'cenimagni',
#  'watching',
#  'combat',
#  'unfinished',
#  'trials',
#  'inculcate',
#  'darkness',
#  'balbus',
#  'homes',
#  'laths',
#  'anartes',
#  'faints',
#  'furthermore',
#  'peaceful',
#  'segonax',
#  'virtuous',
#  'charmed',
#  'contracts',
#  'remembered',
#  'signalizing',
#  'therein',
#  'eternal',
#  'thomas',
#  'inconsiderate',
#  'santoni',
#  'rigging',
#  'disastrous',
#  'unreservedly',
#  'swim',
#  'rebel',
#  'fruitful',
#  'avert',
#  'countermined',
#  'drop',
#  'suevan',
#  'incensed',
#  'pulled',
#  'succumb',
#  'frighten',
#  'intimation',
#  'boasted',
#  'lull',
#  'paemani',
#  'faggots',
#  'reminded',
#  'rutilus',
#  'throng',
#  'alternate',
#  'intervene',
#  'price',
#  'ausci',
#  'keels',
#  'evident',
#  'detaches',
#  'inflecting',
#  'rufus',
#  'knock',
#  'faithfully',
#  'amassed',
#  'discompose',
#  'adviser',
#  'senonian',
#  'obeys',
#  'greeks',
#  'volunteers',
#  'plighted',
#  'sanctity',
#  'interposed',
#  'heaven',
#  'foregoing',
#  'engendered',
#  'reclining',
#  'toils',
#  'capture',
#  'visits',
#  'unsightly',
#  'defeats',
#  'cavarillus',
#  'domitius',
#  'amity',
#  'managed',
#  'consequently',
#  'marshaling',
#  'caleti',
#  'forthwith',
#  'certainty',
#  'dialect',
#  'sentones',
#  'hides',
#  'boiling',
#  'imminent',
#  'honored',
#  'seizes',
#  'ligatures',
#  'overhanging',
#  'detention',
#  'acquitting',
#  'entrances',
#  'replaced',
#  'roam',
#  'launching',
#  'expatiated',
#  'strictness',
#  'overruled',
#  'deceit',
#  'unauthorized',
#  'imputation',
#  'shuddered',
#  'contiguous',
#  'endured',
#  'enactment',
#  'lip',
#  'suffers',
#  'marne',
#  'overmatched',
#  'exceed',
#  'agitator',
#  'leuci',
#  'carcaso',
#  'upright',
#  'dispersing',
#  'brannovices',
#  'harvest',
#  'freed',
#  'undeservedly',
#  'defrauded',
#  'indolence',
#  'alexandrian',
#  'aquileia',
#  'egress',
#  'witness',
#  'suggests',
#  'scale',
#  'feigning',
#  'cita',
#  'liberally',
#  'derived',
#  'flow',
#  'wills',
#  'stirred',
#  'repent',
#  'flee',
#  'sloops',
#  'covetousness',
#  'draughted',
#  'respected',
#  'undone',
#  'imperfect',
#  'bid',
#  'sovereign',
#  'sixth',
#  'dealt',
#  'orcynia',
#  'bushnell',
#  'embarkations',
#  'perilous',
#  'stages',
#  'faces',
#  'confine',
#  'acquaintance',
#  'mine',
#  'administer',
#  'lugotorix',
#  'inroads',
#  'labors',
#  'detestable',
#  'grown',
#  'ports',
#  'snatches',
#  'calenus',
#  'erred',
#  'competitor',
#  'dye',
#  'movable',
#  'undergoing',
#  'therewith',
#  'ascertaining',
#  'shame',
#  'admired',
#  'male',
#  'espoused',
#  'overthrowing',
#  'contests',
#  'preventing',
#  'submissive',
#  'compensation',
#  ...]

# %%
fdist1.max()
# Out:
# 'the'

# %% [markdown]
# We can utilize NLTK's stopwords module to clean the list a bit further by removing stop words from our current universe. This should remove words such as 'the', 'at', etc.

# %%
from nltk.corpus import stopwords
stopwords=stopwords.words('english')
mynewtokens=[w for w in tokens if w not in stopwords]
Fdist2=nltk.FreqDist(mynewtokens)
print(Fdist2)
# Out:
# <FreqDist with 5463 samples and 38612 outcomes>

# %% [markdown]
# This brings down our universe to 38,612 tokens. And we can find out the most common words below.

# %%
Fdist2.most_common(10)
# Out:
# [('caesar', 481),
#  ('chapter', 402),
#  ('enemy', 359),
#  ('men', 314),
#  ('great', 299),
#  ('camp', 292),
#  ('one', 248),
#  ('could', 238),
#  ('would', 235),
#  ('war', 205)]

# %%
Fdist2.most_common(5)
# Out:
# [('caesar', 481),
#  ('chapter', 402),
#  ('enemy', 359),
#  ('men', 314),
#  ('great', 299)]

# %% [markdown]
# Now that we have the 5 most common words, we can use Pandas and Bokeh to visualize them with a bar chart. And we can apply them to the 5 least common words and visualize that set.

# %%
import pandas as pd
from bokeh.charts import Bar
from bokeh.io import output_notebook, show
output_notebook()
dict = {'frequency': {u'caesar': 481, u'chapter': 402, u'enemy': 359, u'men':314, u'great':299}}
df = pd.DataFrame(dict)
df['word'] = df.index
df
p = Bar(df, values='frequency',label='word')
show(p)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fc641619-febc-4839-b22e-73b21be8126c">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="75f945eb-1a3e-4d83-969f-1d1440c70fd1"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("75f945eb-1a3e-4d83-969f-1d1440c70fd1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '75f945eb-1a3e-4d83-969f-1d1440c70fd1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"4cba289a-c471-4b7b-afe4-24e14fdcb114":{"roots":{"references":[{"attributes":{},"id":"a797d63f-b8de-44a2-ba08-f11b39e76bb3","type":"CategoricalTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1084617d-1a2a-4950-8af6-92253725a7b0","type":"Rect"},{"attributes":{"data_source":{"id":"1e1e4857-bfb1-4915-ad97-df7d672e7adc","type":"ColumnDataSource"},"glyph":{"id":"f44f7ca8-de3b-4eb1-83a9-db4b0f8b5597","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2e42179c-7bc1-414c-8171-2fb0d890ae2a","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"4f9e6833-ee32-46fe-a455-006c1f55ef68","subtype":"Chart","type":"Plot"}},"id":"527caf9b-e5ac-4f75-9ccb-cd08e1259a05","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["color","width","line_alpha","line_color","y","fill_alpha","height","x"],"data":{"chart_index":[{"word":"enemy"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[359.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"word":["enemy"],"x":["enemy"],"y":[179.5]}},"id":"a1a529f5-1b5d-4d08-b305-46c7fdfe19d1","type":"ColumnDataSource"},{"attributes":{},"id":"7138651c-911c-4a5c-bc2f-089b9eb356e8","type":"CategoricalTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b3311d55-9456-4038-ac37-27f78500a300","type":"Rect"},{"attributes":{"axis_label":"Sum( Frequency )","formatter":{"id":"68797bb5-8aee-4813-8e4c-ec9cd79aafec","type":"BasicTickFormatter"},"plot":{"id":"4f9e6833-ee32-46fe-a455-006c1f55ef68","subtype":"Chart","type":"Plot"},"ticker":{"id":"835d4a85-4aad-48b0-8241-94147a3b3a7b","type":"BasicTicker"}},"id":"a75698de-ae72-472f-9582-9d7abcd02ee4","type":"LinearAxis"},{"attributes":{"plot":{"id":"4f9e6833-ee32-46fe-a455-006c1f55ef68","subtype":"Chart","type":"Plot"}},"id":"3438f740-f637-4e50-805f-6d8f50f0c68d","type":"PreviewSaveTool"},{"attributes":{"callback":null,"column_names":["color","width","line_alpha","line_color","y","fill_alpha","height","x"],"data":{"chart_index":[{"word":"chapter"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[402.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"word":["chapter"],"x":["chapter"],"y":[201.0]}},"id":"e1ff9816-4bbf-4e06-9279-a4271e6f6539","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"4f9e6833-ee32-46fe-a455-006c1f55ef68","subtype":"Chart","type":"Plot"},"ticker":{"id":"835d4a85-4aad-48b0-8241-94147a3b3a7b","type":"BasicTicker"}},"id":"92b3a089-a842-4300-9dc2-cb622db511cd","type":"Grid"},{"attributes":{"data_source":{"id":"fe2aa789-a1e3-43e4-ad1c-0b46be3158db","type":"ColumnDataSource"},"glyph":{"id":"1084617d-1a2a-4950-8af6-92253725a7b0","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"40146271-0dc3-4781-a690-fd5268a6edff","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"060f2b64-d0df-4ce0-90cf-24b7c55e001a","type":"BoxAnnotation"},"plot":{"id":"4f9e6833-ee32-46fe-a455-006c1f55ef68","subtype":"Chart","type":"Plot"}},"id":"9ca9807a-a101-4d87-b1c2-dfe380dfb3b6","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"19c0062c-f11c-40c0-bde1-256c254f788f","type":"ColumnDataSource"},"glyph":{"id":"c16ef6e2-b21c-4128-b684-e38594773d37","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"18352f9a-ab76-4c61-b68d-ec571cbdd0ba","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"e1ff9816-4bbf-4e06-9279-a4271e6f6539","type":"ColumnDataSource"},"glyph":{"id":"2dab3ff8-74d7-4c33-b1e0-2c4fcf255162","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyp ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[11]</strong>&gt;</code></p>

# %%
Fdist2.most_common()[-5:]
# Out:
# [('south', 1), ('measured', 1), ('fugitives', 1), ('deeper', 1), ('spend', 1)]

# %%
import pandas as pd
from bokeh.charts import Bar
from bokeh.io import output_notebook, show
output_notebook()
dict = {'frequency': {u'south':1, u'measured':1, u'fugitive':1, u'deeper' :1, u'spend':1}}
df = pd.DataFrame(dict)
df['word'] = df.index
df
p = Bar(df, values='frequency',label='word')
show(p)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0710a5fb-43b4-48b0-9ab4-304ec5ae512f">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="aadf27e6-6487-4200-aaef-b890573752ff"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("aadf27e6-6487-4200-aaef-b890573752ff");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'aadf27e6-6487-4200-aaef-b890573752ff' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"90edf197-2da3-4318-870f-64ba6dde8ab1":{"roots":{"references":[{"attributes":{"plot":{"id":"ef0cad8e-da52-474c-8ccc-3b010ce0b633","subtype":"Chart","type":"Plot"}},"id":"d70bd03a-61e1-4993-8b08-d73223b97d10","type":"PreviewSaveTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1084617d-1a2a-4950-8af6-92253725a7b0","type":"Rect"},{"attributes":{"data_source":{"id":"1e1e4857-bfb1-4915-ad97-df7d672e7adc","type":"ColumnDataSource"},"glyph":{"id":"f44f7ca8-de3b-4eb1-83a9-db4b0f8b5597","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2e42179c-7bc1-414c-8171-2fb0d890ae2a","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"4f9e6833-ee32-46fe-a455-006c1f55ef68","subtype":"Chart","type":"Plot"}},"id":"527caf9b-e5ac-4f75-9ccb-cd08e1259a05","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2dab3ff8-74d7-4c33-b1e0-2c4fcf255162","type":"Rect"},{"attributes":{"data_source":{"id":"64868e7d-c0e2-4ce6-996c-f5e671b1b6ce","type":"ColumnDataSource"},"glyph":{"id":"243d38af-c9e3-4a41-877b-40e2fb9e1735","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"51ba9a1e-29ff-4e81-aed8-970c0a183447","type":"GlyphRenderer"},{"attributes":{},"id":"7138651c-911c-4a5c-bc2f-089b9eb356e8","type":"CategoricalTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9d20a28e-86f8-404c-bd4b-ee0cb8dde09f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b3311d55-9456-4038-ac37-27f78500a300","type":"Rect"},{"attributes":{"axis_label":"Sum( Frequency )","formatter":{"id":"68797bb5-8aee-4813-8e4c-ec9cd79aafec","type":"BasicTickFormatter"},"plot":{"id":"4f9e6833-ee32-46fe-a455-006c1f55ef68","subtype":"Chart","type":"Plot"},"ticker":{"id":"835d4a85-4aad-48b0-8241-94147a3b3a7b","type":"BasicTicker"}},"id":"a75698de-ae72-472f-9582-9d7abcd02ee4","type":"LinearAxis"},{"attributes":{"data_source":{"id":"d0148067-ab19-4d19-9e3c-5378dff14484","type":"ColumnDataSource"},"glyph":{"id":"9d20a28e-86f8-404c-bd4b-ee0cb8dde09f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e93f9fcd-519c-470c-af1b-3f7eaee25682","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["color","width","line_alpha","line_color","y","fill_alpha","height","x"],"data":{"chart_index":[{"word":"chapter"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[402.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"word":["chapter"],"x":["chapter"],"y":[201.0]}},"id":"e1ff9816-4bbf-4e06-9279-a4271e6f6539","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"4f9e6833-ee32-46fe-a455-006c1f55ef68","subtype":"Chart","type":"Plot"},"ticker":{"id":"835d4a85-4aad-48b0-8241-94147a3b3a7b","type":"BasicTicker"}},"id":"92b3a089-a842-4300-9dc2-cb622db511cd","type":"Grid"},{"attributes":{"below":[{"id":"6ebcf9fe-24f2-44a1-9956-47f9fdf48ac3","type":"CategoricalAxis"}],"left":[{"id":"a75698de-ae72-472f-9582-9d7abcd02ee4","type":"LinearAxis"}],"legend":null,"renderers":[{"id":"060f2b64-d0df-4ce0-90cf-24b7c55e001a","type":"BoxAnnotation"},{"id":"18352f9a-ab76-4c61-b68d-ec571cbdd0ba","type":"GlyphRenderer"},{"id":"4c5f8883-615a- ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[12]</strong>&gt;</code></p>
